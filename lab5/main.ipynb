# %%
# Importarea bibliotecilor necesare
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importarea csv file
df = pd.read_csv('heart.csv')

# %%
# Afisarea
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
# Afisarea informatiei din fisier
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
# Se verifica daca exista valori egale cu null
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
# Atribuim paramtrului fastingBS sa returneze un obiect de valori unice.
FastingBS = df['FastingBS'].value_counts()

# %%
# Cream o diagrama a datelor, unde acestea sunt impartite intr-un cerc
FastingBS.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='FastingBS'>

# %%
# Cream o diagrama a datelor, unde acestea sunt impartite intr-un cerc
ChestPainType = df['ChestPainType'].value_counts()

# %%
ChestPainType.plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
RestingECG = df['RestingECG'].value_counts()

# %%
RestingECG.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# Reprezentarea prin puncte a 2 valori numerice diferite
sns.scatterplot(data=df, x="Age", y="RestingBP")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='RestingBP'>

# %%
dft = df
dft
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
import numpy as np
# Seaparea coloanelor dupa tipul de date pentru analiza acestora, una pentru caracteristicile categoriale și una pentru caracteristicile numerice.
cat_cols = [col for col in dft.columns if dft[col].dtype == np.object]
num_cols = [col for col in dft.columns if dft[col].dtype != np.object]
# Out:
# C:\Users\Andrew\AppData\Local\Temp\ipykernel_7100\975604256.py:3: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cat_cols = [col for col in dft.columns if dft[col].dtype == np.object]
# C:\Users\Andrew\AppData\Local\Temp\ipykernel_7100\975604256.py:4: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   num_cols = [col for col in dft.columns if dft[col].dtype != np.object]

# %%
# Afisarea cardinalitatii coloanelor categorice
cards = [len(dft[col].unique()) for col in cat_cols]
fig,ax = plt.subplots(figsize=(18,6))
sns.barplot(x=cat_cols, y=cards)
ax.set_xlabel('Feature')
# Out:
# Text(0.5, 0, 'Feature')

# %%
# Distribuția variabilelor categoriale
fig,ax = plt.subplots(figsize=(10,6))
print(dft['Sex'].value_counts() / len(dft))
sns.countplot(dft['Sex'])
ax.set_ylabel('Number of Patients')
ax.set_title('Number of patients by sex')
# Out:
# M    0.78976
# F    0.21024
# Name: Sex, dtype: float64
# d:\proiecte python\laborator nr.5\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of patients by sex')

# %%
# Distribuția colesterolului în funcție de starea bolii
fig,ax = plt.subplots(figsize=(10,6))
data_train_disease = dft[dft['HeartDisease']==1]
data_train_no_disease = dft[dft['HeartDisease']==0]

sns.distplot(data_train_no_disease['Cholesterol'], label='No disease')
sns.distplot(data_train_disease['Cholesterol'], label='Disease')
ax.legend()
ax.set_title('Cholesterol Distribution')
# Out:
# d:\proiecte python\laborator nr.5\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# d:\proiecte python\laborator nr.5\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Cholesterol Distribution')

# %%
#Controlăm numărul vârstelor
plt.figure(figsize=(25,12))
sns.set_context('notebook',font_scale = 1.5)
sns.barplot(x=df.Age.value_counts()[:10].index,y=df.Age.value_counts()[:10].values)
plt.tight_layout()

# %%
#Afișăm relația dintre sex și slope
plt.figure(figsize=(18,9))
sns.set_context('notebook',font_scale = 1.5)
sns.countplot(df['Sex'],hue=df["ST_Slope"])
plt.tight_layout()
# Out:
# d:\proiecte python\laborator nr.5\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Afișarea relației dintre fucții
plt.figure(figsize=(14, 14))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
# Reprezentarea funcțiilor aprte
fig = plt.figure(figsize=(20, 20))
ax = fig.gca()
df.plot(kind='density', subplots=True, layout=(4, 4), sharex=False, ax=ax)
plt.show()
# Out:
# C:\Users\Andrew\AppData\Local\Temp\ipykernel_7100\2487845625.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.plot(kind='density', subplots=True, layout=(4, 4), sharex=False, ax=ax)

# %%
# Reprezentăm diagrama cu case pentru fiecăre funcție.
fig = plt.figure(figsize=(20, 20))
ax = fig.gca()
df.plot(kind='box', subplots=True, layout=(4, 4), sharex=False, ax=ax)
plt.show()
# Out:
# C:\Users\Andrew\AppData\Local\Temp\ipykernel_7100\2518813709.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.plot(kind='box', subplots=True, layout=(4, 4), sharex=False, ax=ax)

# %%
df_copy = df

# %%
df_copy.to_csv('heart_numeric.csv', index=False)
